# %%
import pandas as pd
import numpy as np
data=pd.read_csv('D:/Jupyterfile/WorldIndex.csv')
data
# Out:
#        Country      Continent  Life_expectancy  GDP_per_capita  Population
# 0      Algeria         Africa        75.042537     4132.760292  39871528.0
# 1       Angola         Africa        52.666098     3695.793748  27859305.0
# 2        Benin         Africa        59.720707      783.947091  10575952.0
# 3     Botswana         Africa        64.487415     6532.060501   2209197.0
# 4      Burundi         Africa        57.107049      303.681022  10199270.0
# ..         ...            ...              ...             ...         ...
# 172   Paraguay  South America        73.025634     4109.367724   6639119.0
# 173       Peru  South America        74.780732     6030.343259  31376671.0
# 174   Suriname  South America        71.294171     8818.982566    553208.0
# 175    Uruguay  South America        77.138220    15524.842470   3431552.0
# 176  Venezuela  South America        74.409610             NaN  31155134.0
#
# [177 rows x 5 columns]

# %%
data.isnull()#查看所有缺失值
data2=data.dropna()
print(data2)
# Out:
#       Country      Continent  Life_expectancy  GDP_per_capita  Population
# 0     Algeria         Africa        75.042537     4132.760292  39871528.0
# 1      Angola         Africa        52.666098     3695.793748  27859305.0
# 2       Benin         Africa        59.720707      783.947091  10575952.0
# 3    Botswana         Africa        64.487415     6532.060501   2209197.0
# 4     Burundi         Africa        57.107049      303.681022  10199270.0
# ..        ...            ...              ...             ...         ...
# 171    Guyana  South America        66.507512     4136.689919    768514.0
# 172  Paraguay  South America        73.025634     4109.367724   6639119.0
# 173      Peru  South America        74.780732     6030.343259  31376671.0
# 174  Suriname  South America        71.294171     8818.982566    553208.0
# 175   Uruguay  South America        77.138220    15524.842470   3431552.0
#
# [164 rows x 5 columns]

# %% [markdown]
#  # 人均寿命直方图

# %%
dataset1 = data["Life_expectancy"]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(dataset1, bins=10)
# Out:
# (array([ 5.,  5.,  9., 11., 17., 16., 20., 41., 17., 28.]),
#  array([48.87395122, 52.37092195, 55.86789268, 59.36486342, 62.86183415,
#         66.35880488, 69.85577561, 73.35274634, 76.84971708, 80.34668781,
#         83.84365854]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # 人均GDP直方图

# %%
dataset2 = data["GDP_per_capita"]
fig, ax = plt.subplots(figsize=(15, 5))
ax.hist(dataset2, bins=30)
# Out:
# (array([64., 36., 15., 12.,  6.,  4.,  6.,  1.,  2.,  0.,  3.,  3.,  6.,
#          0.,  2.,  2.,  2.,  1.,  0.,  1.,  0.,  1.,  0.,  1.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([   303.6810223 ,   3690.55239822,   7077.42377415,  10464.29515007,
#          13851.16652599,  17238.03790192,  20624.90927784,  24011.78065376,
#          27398.65202969,  30785.52340561,  34172.39478153,  37559.26615746,
#          40946.13753338,  44333.0089093 ,  47719.88028523,  51106.75166115,
#          54493.62303707,  57880.494413  ,  61267.36578892,  64654.23716484,
#          68041.10854077,  71427.97991669,  74814.85129261,  78201.72266854,
#          81588.59404446,  84975.46542038,  88362.33679631,  91749.20817223,
#          95136.07954815,  98522.95092408, 101909.8223    ]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# # 人均寿命箱线图

# %%
data.Life_expectancy.plot.box()

# %% [markdown]
# # 绘制每个大洲的国家个数条形图

# %%
continent=data.groupby('Continent').Country.count()
continent.plot(kind='bar')

# %% [markdown]
# # 绘制各大洲国家数量占比的饼图# 绘制各大洲国家数量占比的饼图

# %%
continent.index
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'Oceania',
#        'South America'],
#       dtype='object', name='Continent')

# %%
plt.pie(continent,labels=continent.index,autopct='%1.1f%%',shadow=False,startangle=100)#labels=labels
plt.show()

# %% [markdown]
# # 绘制人均寿命和人均GDP的关系（散点）

# %%
x=data.Life_expectancy
y=data.GDP_per_capita#与random.randint表示含义不同
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # 人均GDP与人均寿命的气泡图（数据点大小，正比于人口数，给不同洲的国家设置不同的颜色）

# %%
fig, ax = plt.subplots()
#color = list(data_new.Country)
color = np.random.rand(len(list(data.Country)))
#分别设置X轴值，Y轴值，以及第三个参数值大小来显示气泡大小
ax.scatter(data.GDP_per_capita,data.Life_expectancy,s = list(data.Population/200000),c=color,alpha=0.6)
#ax.plot(10*np.random.randn(100),10*np.random.randn(100),"o")
ax.set_title("气泡图",fontproperties = "simHei",fontsize = 16)
ax.set_xlabel("GDP值",fontproperties = "simHei",fontsize = 14)
ax.set_ylabel("平均寿命",fontproperties = "simHei",fontsize = 14)
ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# # ①求解f(x)=2*sin(x)-x+1

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import root,fsolve

rangex1 = np.linspace(-2,8)
rangey1_1,rangey1_2 = 2*np.sin(rangex1),rangex1
plt.figure(1)
plt.plot(rangex1,rangey1_1,'r',rangex1,rangey1_2,'b--')
plt.title('$2sin(x)$ and $x-1$')

f1=lambda x:np.sin(x)*2-x+1
sol1_root = root(f1,[0])
print('sol1_root:',sol1_root)
print('sol1_root.x',sol1_root.x)
sol1_fsolve = fsolve(f1,[0])
print('sol1_fsolve:',sol1_fsolve)
# Out:
# sol1_root:     fjac: array([[-1.]])
#      fun: array([0.31514905])
#  message: 'The iteration is not making good progress, as measured by the \n  improvement from the last ten iterations.'
#     nfev: 24
#      qtf: array([-0.31514905])
#        r: array([0.00451924])
#   status: 5
#  success: False
#        x: array([-1.04882813])
# sol1_root.x [-1.04882813]
# sol1_fsolve: [-1.04882813]
# D:\program\ananconda\lib\site-packages\scipy\optimize\minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# # ②求解线性方程组{3X1+2X2=3;X1-2X2=5}

# %%
from sympy import *
x1 = Symbol('x1')
x2 = Symbol('x2')
print (solve([3 * x1 + 2*x2 - 3, x1 - 2*x2-5],[x1, x2]))
# Out:
# {x1: 2, x2: -3/2}
