# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('D:/Learn/课程/第三学期/python数学运算与数据可视化/作业/第二次/WorldIndex.csv')

# %%
data
# Out:
#                       Country      Continent  Life_expectancy  GDP_per_capita  \
# 0                     Algeria         Africa        75.042537     4132.760292
# 1                      Angola         Africa        52.666098     3695.793748
# 2                       Benin         Africa        59.720707      783.947091
# 3                    Botswana         Africa        64.487415     6532.060501
# 4                     Burundi         Africa        57.107049      303.681022
# 5                    Cameroon         Africa        55.934390     1244.429421
# 6    Central African Republic         Africa        51.419122      348.381417
# 7                        Chad         Africa        51.873317      777.248705
# 8                     Comoros         Africa        63.554024      727.646387
# 9                       Congo         Africa        62.867659     1712.121131
# 10                   Djibouti         Africa        62.285659     1862.167274
# ...

# %% [markdown]
# 去除空值

# %%
data1=data.dropna()
data1
# Out:
#                       Country      Continent  Life_expectancy  GDP_per_capita  \
# 0                     Algeria         Africa        75.042537     4132.760292
# 1                      Angola         Africa        52.666098     3695.793748
# 2                       Benin         Africa        59.720707      783.947091
# 3                    Botswana         Africa        64.487415     6532.060501
# 4                     Burundi         Africa        57.107049      303.681022
# 5                    Cameroon         Africa        55.934390     1244.429421
# 6    Central African Republic         Africa        51.419122      348.381417
# 7                        Chad         Africa        51.873317      777.248705
# 8                     Comoros         Africa        63.554024      727.646387
# 9                       Congo         Africa        62.867659     1712.121131
# 10                   Djibouti         Africa        62.285659     1862.167274
# ...

# %% [markdown]
# 人均寿命直方图

# %%
Life_expectancy=data1['Life_expectancy']

# %%
bins = np.linspace(min(Life_expectancy),max(Life_expectancy),20)
plt.hist(Life_expectancy,bins)
plt.xlabel('Life_expectancy')
plt.ylabel('The number of occurences')
plt.title('Frequency distribution of number of Life_expectancy')
plt.show()

# %% [markdown]
# 人均GDP直方图

# %%
GDP_per_capita=data1['GDP_per_capita']

# %%
bins = np.linspace(min(GDP_per_capita),max(GDP_per_capita),20)
plt.hist(GDP_per_capita,bins)
plt.xlabel('GDP_per_capita')
plt.ylabel('Number of occurences')
plt.title('Frequency distribution of number of GDP_per_capita')
plt.show()

# %% [markdown]
# 人均寿命箱线图

# %%
Life_expectancy.plot.box()

# %% [markdown]
# 绘制每个大洲的国家个数条形图

# %%
continent=data1.groupby('Continent').Country.count()
continent.plot(kind='bar')

# %% [markdown]
# 绘制各大洲国家数量占比的饼图

# %%
continent.index
plt.pie(continent,labels=continent.index,autopct='%1.1f%%',shadow=False,startangle=100)#labels=labels
plt.show()

# %% [markdown]
# 绘制人均寿命和人均GDP的关系（散点）

# %%
plt.scatter(Life_expectancy,GDP_per_capita)
plt.show()

# %% [markdown]
# 人均GDP与人均寿命的气泡图（数据点大小，正比于人口数，给不同洲的国家设置不同的颜色）

# %%
fig, ax = plt.subplots()
color = np.random.rand(len(list(data1.Country)))
ax.scatter(GDP_per_capita,Life_expectancy,s = list(data1.Population/200000),c=color,alpha=0.6)
ax.set_title("气泡图",fontproperties = "simHei",fontsize = 16)
ax.set_xlabel("GDP值",fontproperties = "simHei",fontsize = 14)
ax.set_ylabel("平均寿命",fontproperties = "simHei",fontsize = 14)
ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Scipy解方程

# %% [markdown]
# 求解f(x)=2*sin(x)-x+1

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import root,fsolve

rangex1 = np.linspace(-2,8)
rangey1_1,rangey1_2 = 2*np.sin(rangex1),rangex1
plt.figure(1)
plt.plot(rangex1,rangey1_1,'r',rangex1,rangey1_2,'b--')
plt.title('$2sin(x)$ and $x-1$')

f1=lambda x:np.sin(x)*2-x+1
sol1_root = root(f1,[0])
print('sol1_root:',sol1_root)
print('sol1_root.x',sol1_root.x)
sol1_fsolve = fsolve(f1,[0])
print('sol1_fsolve:',sol1_fsolve)
print('----------------')
# Out:
# sol1_root:     fjac: array([[-1.]])
#      fun: array([0.31514905])
#  message: 'The iteration is not making good progress, as measured by the \n  improvement from the last ten iterations.'
#     nfev: 24
#      qtf: array([-0.31514905])
#        r: array([0.00451924])
#   status: 5
#  success: False
#        x: array([-1.04882813])
# sol1_root.x [-1.04882813]
# sol1_fsolve: [-1.04882813]
# ----------------
# D:\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# 求解线性方程组{3X1+2X2=3;X1-2X2=5}

# %%
import numpy as np
A=np.mat('3,2;1,-2')
B=np.mat('3,5').T
R=np.linalg.solve(A,B)
R
# Out:
# matrix([[ 2. ],
#         [-1.5]])

# %%
from sympy import *
x1 = Symbol('x1')
x2 = Symbol('x2')
solve([3 * x1 + 2*x2 - 3, x1 - 2*x2-5],[x1, x2])
# Out:
# {x1: 2, x2: -3/2}
